# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.feature_selection import mutual_info_regression

from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn import metrics
import pickle

# %matplotlib inline

# %%
df = pd.read_csv('bodyfat.csv')

# %%
df
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# 1     58.7  37.3   23.4    30.5     28.9   18.2
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 4     63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...   ...    ...     ...      ...    ...
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Density  252 non-null    float64
#  1   BodyFat  252 non-null    float64
#  2   Age      252 non-null    int64
#  3   Weight   252 non-null    float64
#  4   Height   252 non-null    float64
#  5   Neck     252 non-null    float64
#  6   Chest    252 non-null    float64
#  7   Abdomen  252 non-null    float64
#  8   Hip      252 non-null    float64
#  9   Thigh    252 non-null    float64
#  10  Knee     252 non-null    float64
#  11  Ankle    252 non-null    float64
#  12  Biceps   252 non-null    float64
#  13  Forearm  252 non-null    float64
#  14  Wrist    252 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 29.7 KB

# %%
df.corr()
# Out:
#           Density   BodyFat       Age    Weight    Height      Neck     Chest  \
# Density  1.000000 -0.987782 -0.277637 -0.594062  0.097881 -0.472966 -0.682599
# BodyFat -0.987782  1.000000  0.291458  0.612414 -0.089495  0.490592  0.702620
# Age     -0.277637  0.291458  1.000000 -0.012746 -0.171645  0.113505  0.176450
# Weight  -0.594062  0.612414 -0.012746  1.000000  0.308279  0.830716  0.894191
# Height   0.097881 -0.089495 -0.171645  0.308279  1.000000  0.253710  0.134892
# Neck    -0.472966  0.490592  0.113505  0.830716  0.253710  1.000000  0.784835
# Chest   -0.682599  0.702620  0.176450  0.894191  0.134892  0.784835  1.000000
# Abdomen -0.798955  0.813432  0.230409  0.887995  0.087813  0.754077  0.915828
# Hip     -0.609331  0.625201 -0.050332  0.940884  0.170394  0.734958  0.829420
# Thigh   -0.553091  0.559608 -0.200096  0.868694  0.148436  0.695697  0.729859
# Knee    -0.495040  0.508665  0.017516  0.853167  0.286053  0.672405  0.719496
# Ankle   -0.264890  0.265970 -0.105058  0.613685  0.264744  0.477892  0.482988
# Biceps  -0.487109  0.493271 -0.041162  0.800416  0.207816  0.731146  0.727907
# Forearm -0.351648  0.361387 -0.085056  0.630301  0.228649  0.623660  0.580173
# Wrist   -0.325716  0.346575  0.213531  0.729775  0.322065  0.744826  0.660162
#
#           Abdomen       Hip     Thigh      Knee     Ankle    Biceps   Forearm  \
# Density -0.798955 -0.609331 -0.553091 -0.495040 -0.264890 -0.487109 -0.351648
# BodyFat  0.813432  0.625201  0.559608  0.508665  0.265970  0.493271  0.361387
# Age      0.230409 -0.050332 -0.200096  0.017516 -0.105058 -0.041162 -0.085056
# Weight   0.887995  0.940884  0.868694  0.853167  0.613685  0.800416  0.630301
# Height   0.087813  0.170394  0.148436  0.286053  0.264744  0.207816  0.228649
# Neck     0.754077  0.734958  0.695697  0.672405  0.477892  0.731146  0.623660
# Chest    0.915828  0.829420  0.729859  0.719496  0.482988  0.727907  0.580173
# Abdomen  1.000000  0.874066  0.766624  0.737179  0.453223  0.684983  0.503316
# Hip      0.874066  1.000000  0.896410  0.823473  0.558387  0.739273  0.545014
# Thigh    0.766624  0.896410  1.000000  0.799170  0.539797  0.761477  0.566842
# Knee     0.737179  0.823473  0.799170  1.000000  0.611608  0.678709  0.555898
# Ankle    0.453223  0.558387  0.539797  0.611608  1.000000  0.484855  0.419050
# Biceps   0.684983  0.739273  0.761477  0.678709  0.484855  1.000000  0.678255
# Forearm  0.503316  0.545014  0.566842  0.555898  0.419050  0.678255  1.000000
# Wrist    0.619832  0.630090  0.558685  0.664507  0.566195  0.632126  0.585588
#
#             Wrist
# Density -0.325716
# BodyFat  0.346575
# Age      0.213531
# Weight   0.729775
# Height   0.322065
# Neck     0.744826
# Chest    0.660162
# Abdomen  0.619832
# Hip      0.630090
# Thigh    0.558685
# Knee     0.664507
# Ankle    0.566195
# Biceps   0.632126
# Forearm  0.585588
# Wrist    1.000000

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(), annot=True,cmap='viridis')

# %%
sns.distplot(df)
# Out:
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\107776459.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df)

# %%
# checking relation of body-fat with all columns
def dist_plot(col):
    plt.figure(figsize=(12,6))
    sns.distplot(df['BodyFat'], hist=False, label='BodyFat')
    sns.distplot(df[col], color='red',  hist=False,label=col)
    plt.legend()
    plt.show()
    

cols = list(df.columns)

for i in cols:
    print(f"Distribution plots for {i} feature")
    dist_plot(i)
# Out:
# Distribution plots for Density feature
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'], hist=False, label='BodyFat')
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], color='red',  hist=False,label=col)
# Distribution plots for BodyFat feature
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'], hist=False, label='BodyFat')
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], color='red',  hist=False,label=col)
# Distribution plots for Age feature
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'], hist=False, label='BodyFat')
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], color='red',  hist=False,label=col)
# Distribution plots for Weight feature
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'], hist=False, label='BodyFat')
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], color='red',  hist=False,label=col)
# Distribution plots for Height feature
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'], hist=False, label='BodyFat')
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], color='red',  hist=False,label=col)
# Distribution plots for Neck feature
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'], hist=False, label='BodyFat')
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], color='red',  hist=False,label=col)
# Distribution plots for Chest feature
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'], hist=False, label='BodyFat')
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], color='red',  hist=False,label=col)
# Distribution plots for Abdomen feature
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'], hist=False, label='BodyFat')
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], color='red',  hist=False,label=col)
# Distribution plots for Hip feature
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'], hist=False, label='BodyFat')
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], color='red',  hist=False,label=col)
# Distribution plots for Thigh feature
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'], hist=False, label='BodyFat')
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], color='red',  hist=False,label=col)
# Distribution plots for Knee feature
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'], hist=False, label='BodyFat')
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], color='red',  hist=False,label=col)
# Distribution plots for Ankle feature
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'], hist=False, label='BodyFat')
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], color='red',  hist=False,label=col)
# Distribution plots for Biceps feature
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'], hist=False, label='BodyFat')
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], color='red',  hist=False,label=col)
# Distribution plots for Forearm feature
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'], hist=False, label='BodyFat')
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], color='red',  hist=False,label=col)
# Distribution plots for Wrist feature
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'], hist=False, label='BodyFat')
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\173799047.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], color='red',  hist=False,label=col)

# %%
def plots(df,col):
    plt.figure(figsize=(15,8))
    plt.subplot(1,3,1)
    plt.hist(df[col])
    
    plt.subplot(1,3,2)
    stats.probplot(df[col], dist='norm', plot=plt)
    
    plt.subplot(1,3,3)
    sns.boxplot(x=df[col])
    plt.show()
    
    
cols = list(df.columns)
for i in range(len(cols)):
    print(f"Distribution plots for the feature {cols[i]}")
    
    plots(df,cols[i])
# Out:
# Distribution plots for the feature Density
# Distribution plots for the feature BodyFat
# Distribution plots for the feature Age
# Distribution plots for the feature Weight
# Distribution plots for the feature Height
# Distribution plots for the feature Neck
# Distribution plots for the feature Chest
# Distribution plots for the feature Abdomen
# Distribution plots for the feature Hip
# Distribution plots for the feature Thigh
# Distribution plots for the feature Knee
# Distribution plots for the feature Ankle
# Distribution plots for the feature Biceps
# Distribution plots for the feature Forearm
# Distribution plots for the feature Wrist

# %%
upperlimit=[]
lowerlimit=[]

for i in df.columns:
    upperlimit.append(df[i].mean()+(df[i].std())*4)
    lowerlimit.append(df[i].mean()-(df[i].std())*4)

# %%
cols = list(df.columns)
j=0
for i in range(len(cols)):
    outliers = df.loc[(df[cols[i]]>upperlimit[j])&(df[cols[i]]<lowerlimit[j])]
    j+=1

# %%
outliers
# Out:
# Empty DataFrame
# Columns: [Density, BodyFat, Age, Weight, Height, Neck, Chest, Abdomen, Hip, Thigh, Knee, Ankle, Biceps, Forearm, Wrist]
# Index: []

# %%
train_data = df.drop('BodyFat', axis=1)

# %%
test_data = df['BodyFat']

# %% [markdown]
# ### Using ExtraTreesRegressor for feature selection

# %%
etr = ExtraTreesRegressor()
etr.fit(train_data,test_data)
# Out:
# ExtraTreesRegressor()

# %%
etr.feature_importances_
# Out:
# array([7.52726136e-01, 2.07109640e-03, 1.34561888e-02, 2.63709137e-03,
#        5.06479168e-03, 6.03851648e-02, 1.30206093e-01, 5.15695985e-03,
#        9.30762647e-03, 8.32627970e-03, 6.43773587e-04, 7.10788392e-03,
#        8.49794065e-04, 2.06112007e-03])

# %%
series = pd.Series(etr.feature_importances_, index = train_data.columns)
series.plot(kind='barh')

# %%
series = pd.Series(etr.feature_importances_, index = train_data.columns)
series.nlargest(5).plot(kind='barh')

# %% [markdown]
# ### Using Mutual Information Gain for feature selection

# %%
mr = mutual_info_regression(train_data, test_data)

# %%
plotdata_mi = pd.Series(mr, index=train_data.columns)
plotdata_mi.plot(kind='barh')

# %%
plotdata_mi = pd.Series(mr, index=train_data.columns)
plotdata_mi.nlargest(5).plot(kind='barh')

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, cmap='viridis')

# %%
def correlation(df, threshold):
    colcor = set()
    cormat = df.corr()
    for i in range(len(cormat)):
        for j in range(i):
            if abs(cormat.iloc[i][j])>threshold:
                colname = cormat.columns[i]
                colcor.add(colname)
                
    return colcor

correlation(train_data, threshold=0.85)
# Out:
# {'Abdomen', 'Chest', 'Hip', 'Knee', 'Thigh'}

# %% [markdown]
# ###### From the above feature selection tehniques, the features recommended by the ExtraTreesRegressor and mutual informatio gain are correct and from the correlation map we get the similar pattern. We noticed that Abdomen and Hip are having similar features. They're having a collinearity, same goes with the knee and thigh, we can either keep any one of them and we noticed that the feature Abdomen gave more feature importance score in comparison to Hip, so will be selecting that.

# %%
temp = df[list(df.columns)]

# %%
info = pd.DataFrame()
info['VIF'] = [variance_inflation_factor(temp.values, i ) for i in range(temp.shape[1])]
info['Column'] = temp.columns
info
# Out:
#             VIF   Column
# 0   3695.622377  Density
# 1     33.845429  BodyFat
# 2     31.376101      Age
# 3   1238.097164   Weight
# 4    613.410514   Height
# 5   1081.965633     Neck
# 6   1374.457425    Chest
# 7   1332.624257  Abdomen
# 8   2933.636131      Hip
# 9   1017.257501    Thigh
# 10  1187.890413     Knee
# 11   356.293529    Ankle
# 12   419.391664   Biceps
# 13   454.571766  Forearm
# 14  1349.973920    Wrist

# %% [markdown]
# ###### We'll go with the weight and hip method as Hip and Thigh are very much related, so we'll select the Density, Abdomen, Chest, Hip, Weight features and drop every ohter feature, if that doesn't produce any further importance we will try with some other feature

# %%
df
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# 1     58.7  37.3   23.4    30.5     28.9   18.2
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 4     63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...   ...    ...     ...      ...    ...
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]

# %%
df_train = df[['Density', 'Abdomen', 'Chest', 'Hip', 'Weight']]

# %%
df_train
# Out:
#      Density  Abdomen  Chest    Hip  Weight
# 0     1.0708     85.2   93.1   94.5  154.25
# 1     1.0853     83.0   93.6   98.7  173.25
# 2     1.0414     87.9   95.8   99.2  154.00
# 3     1.0751     86.4  101.8  101.2  184.75
# 4     1.0340    100.0   97.3  101.9  184.25
# ..       ...      ...    ...    ...     ...
# 247   1.0736     83.6   89.2   88.8  134.25
# 248   1.0236    105.0  108.5  104.5  201.00
# 249   1.0328    111.5  111.1  101.7  186.75
# 250   1.0399    101.3  108.3   97.8  190.75
# 251   1.0271    108.5  112.4  107.1  207.50
#
# [252 rows x 5 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df_train,test_data, test_size=0.2)

# %%
X_train.shape
# Out:
# (201, 5)

# %%
X_test.shape
# Out:
# (51, 5)

# %%
dtr = DecisionTreeRegressor()

# %%
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
plt.figure(figsize=(15,7))
tree.plot_tree(dtr, filled=True)
# Out:
# [Text(0.4990418632075472, 0.9583333333333334, 'X[0] <= 1.056\nsquared_error = 67.838\nsamples = 201\nvalue = 19.044'),
#  Text(0.2202240566037736, 0.875, 'X[0] <= 1.039\nsquared_error = 21.849\nsamples = 105\nvalue = 25.533'),
#  Text(0.09345518867924528, 0.7916666666666666, 'X[0] <= 1.029\nsquared_error = 9.303\nsamples = 41\nvalue = 30.432'),
#  Text(0.04363207547169811, 0.7083333333333334, 'X[0] <= 1.014\nsquared_error = 4.306\nsamples = 17\nvalue = 33.488'),
#  Text(0.03891509433962264, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 40.1'),
#  Text(0.04834905660377359, 0.625, 'X[0] <= 1.024\nsquared_error = 1.672\nsamples = 16\nvalue = 33.075'),
#  Text(0.02122641509433962, 0.5416666666666666, 'X[2] <= 117.25\nsquared_error = 0.276\nsamples = 6\nvalue = 34.567'),
#  Text(0.009433962264150943, 0.4583333333333333, 'X[3] <= 108.2\nsquared_error = 0.122\nsamples = 2\nvalue = 33.95'),
#  Text(0.0047169811320754715, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 33.6'),
#  Text(0.014150943396226415, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 34.3'),
#  Text(0.0330188679245283, 0.4583333333333333, 'X[0] <= 1.021\nsquared_error = 0.067\nsamples = 4\nvalue = 34.875'),
#  Text(0.02358490566037736, 0.375, 'X[1] <= 133.05\nsquared_error = 0.01\nsamples = 2\nvalue = 35.1'),
#  Text(0.018867924528301886, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 35.0'),
#  Text(0.02830188679245283, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 35.2'),
#  Text(0.04245283018867924, 0.375, 'X[0] <= 1.021\nsquared_error = 0.023\nsamples = 2\nvalue = 34.65'),
#  Text(0.03773584905660377, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 34.8'),
#  Text(0.04716981132075472, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 34.5'),
#  Text(0.07547169811320754, 0.5416666666666666, 'X[0] <= 1.027\nsquared_error = 0.374\nsamples = 10\nvalue = 32.18'),
#  Text(0.0660377358490566, 0.4583333333333333, 'X[0] <= 1.026\nsquared_error = 0.066\nsamples = 6\nvalue = 32.633'),
#  Text(0.06132075471698113, 0.375, 'X[0] <= 1.025\nsquared_error = 0.015\nsamples = 4\nvalue = 32.8'),
#  Text(0.05660377358490566, 0.2916666666666667, 'X[0] <= 1.025\nsquared_error = 0.002\nsamples = 3\nvalue = 32.867'),
#  Text(0.05188679245283019, 0.20833333333333334, 'squared_error = 0.0\nsamples = 2\nvalue = 32.9'),
#  Text(0.06132075471698113, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 32.8'),
#  Text(0.0660377358490566, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 32.6'),
#  Text(0.07075471698113207, 0.375, 'squared_error = -0.0\nsamples = 2\nvalue = 32.3'),
#  Text(0.08490566037735849, 0.4583333333333333, 'X[3] <= 106.75\nsquared_error = 0.065\nsamples = 4\nvalue = 31.5'),
#  Text(0.08018867924528301, 0.375, 'X[4] <= 204.125\nsquared_error = 0.016\nsamples = 3\nvalue = 31.367'),
#  Text(0.07547169811320754, 0.2916666666666667, 'X[1] <= 100.55\nsquared_error = 0.003\nsamples = 2\nvalue = 31.45'),
#  Text(0.07075471698113207, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 31.4'),
#  Text(0.08018867924528301, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 31.5'),
#  Text(0.08490566037735849, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 31.2'),
#  Text(0.08962264150943396, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 31.9'),
#  Text(0.14327830188679244, 0.7083333333333334, 'X[0] <= 1.035\nsquared_error = 1.538\nsamples = 24\nvalue = 28.267'),
#  Text(0.11556603773584906, 0.625, 'X[0] <= 1.032\nsquared_error = 0.391\nsamples = 12\nvalue = 29.367'),
#  Text(0.09905660377358491, 0.5416666666666666, 'X[0] <= 1.031\nsquared_error = 0.142\nsamples = 5\nvalue = 29.98'),
#  Text(0.09433962264150944, 0.4583333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 30.7'),
#  Text(0.10377358490566038, 0.4583333333333333, 'X[0] <= 1.032\nsquared_error = 0.015\nsamples = 4\nvalue = 29.8'),
#  Text(0.09905660377358491, 0.375, 'X[2] <= 104.65\nsquared_error = 0.002\nsamples = 3\nvalue = 29.867'),
#  Text(0.09433962264150944, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 29.8'),
#  Text(0.10377358490566038, 0.2916666666666667, 'X[1] <= 105.4\nsquared_error = 0.0\nsamples = 2\nvalue = 29.9'),
#  Text(0.09905660377358491, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 29.9'),
#  Text(0.10849056603773585, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 29.9'),
#  Text(0.10849056603773585, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 29.6'),
#  Text(0.1320754716981132, 0.5416666666666666, 'X[0] <= 1.034\nsquared_error = 0.108\nsamples = 7\nvalue = 28.929'),
#  Text(0.12264150943396226, 0.4583333333333333, 'X[0] <= 1.033\nsquared_error = 0.032\nsamples = 4\nvalue = 29.175'),
#  Text(0.1179245283018868, 0.375, 'X[4] <= 187.25\nsquared_error = 0.002\nsamples = 2\nvalue = 29.35'),
#  Text(0.11320754716981132, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 29.3'),
#  Text(0.12264150943396226, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 29.4'),
#  Text(0.12735849056603774, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 29.0'),
#  Text(0.14150943396226415, 0.4583333333333333, 'X[0] <= 1.034\nsquared_error = 0.02\nsamples = 3\nvalue = 28.6'),
#  Text(0.13679245283018868, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 28.7'),
#  Text(0.14622641509433962, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 28.4'),
#  Text(0.17099056603773585, 0.625, 'X[0] <= 1.036\nsquared_error = 0.266\nsamples = 12\nvalue = 27.167'),
#  Text(0.15566037735849056, 0.5416666666666666, 'X[4] <= 203.875\nsquared_error = 0.002\nsamples = 3\nvalue = 27.967'),
#  Text(0.1509433962264151, 0.4583333333333333, 'squared_error = -0.0\nsamples = 2\nvalue = 28.0'),
#  Text(0.16037735849056603, 0.4583333333333333, 'squared_error = -0.0\nsamples = 1\nvalue = 27.9'),
#  Text(0.18632075471698112, 0.5416666666666666, 'X[0] <= 1.038\nsquared_error = 0.069\nsamples = 9\nvalue = 26.9'),
#  Text(0.16981132075471697, 0.4583333333333333, 'X[4] <= 172.75\nsquared_error = 0.012\nsamples = 4\nvalue = 27.175'),
#  Text(0.1650943396226415, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 27.0'),
#  Text(0.17452830188679244, 0.375, 'X[0] <= 1.037\nsquared_error = 0.002\nsamples = 3\nvalue = 27.233'),
#  Text(0.16981132075471697, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 27.3'),
#  Text(0.1792452830188679, 0.2916666666666667, 'squared_error = -0.0\nsamples = 2\nvalue = 27.2'),
#  Text(0.2028301886792453, 0.4583333333333333, 'X[0] <= 1.039\nsquared_error = 0.006\nsamples = 5\nvalue = 26.68'),
#  Text(0.19339622641509435, 0.375, 'X[1] <= 90.7\nsquared_error = 0.002\nsamples = 3\nvalue = 26.733'),
#  Text(0.18867924528301888, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 26.8'),
#  Text(0.19811320754716982, 0.2916666666666667, 'squared_error = -0.0\nsamples = 2\nvalue = 26.7'),
#  Text(0.21226415094339623, 0.375, 'X[3] <= 103.0\nsquared_error = 0.0\nsamples = 2\nvalue = 26.6'),
#  Text(0.20754716981132076, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 26.6'),
#  Text(0.2169811320754717, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 26.6'),
#  Text(0.3469929245283019, 0.7916666666666666, 'X[0] <= 1.047\nsquared_error = 4.668\nsamples = 64\nvalue = 22.395'),
#  Text(0.27653301886792453, 0.7083333333333334, 'X[0] <= 1.043\nsquared_error = 0.778\nsamples = 23\nvalue = 24.891'),
#  Text(0.24646226415094338, 0.625, 'X[0] <= 1.041\nsquared_error = 0.191\nsamples = 14\nvalue = 25.486'),
#  Text(0.23113207547169812, 0.5416666666666666, 'X[0] <= 1.04\nsquared_error = 0.019\nsamples = 6\nvalue = 25.933'),
#  Text(0.22641509433962265, 0.4583333333333333, 'X[3] <= 104.3\nsquared_error = 0.002\nsamples = 3\nvalue = 26.067'),
#  Text(0.22169811320754718, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 26.1'),
#  Text(0.23113207547169812, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 26.0'),
#  Text(0.2358490566037736, 0.4583333333333333, 'squared_error = 0.0\nsamples = 3\nvalue = 25.8'),
#  Text(0.2617924528301887, 0.5416666666666666, 'X[0] <= 1.042\nsquared_error = 0.058\nsamples = 8\nvalue = 25.15'),
#  Text(0.25, 0.4583333333333333, 'X[0] <= 1.041\nsquared_error = 0.014\nsamples = 5\nvalue = 25.32'),
#  Text(0.24056603773584906, 0.375, 'X[1] <= 97.6\nsquared_error = 0.002\nsamples = 2\nvalue = 25.45'),
#  Text(0.2358490566037736, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 25.5'),
#  Text(0.24528301886792453, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 25.4'),
#  Text(0.25943396226415094, 0.375, 'X[0] <= 1.041\nsquared_error = 0.002\nsamples = 3\nvalue = 25.233'),
#  Text(0.25471698113207547, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 25.3'),
#  Text(0.2641509433962264, 0.2916666666666667, 'squared_error = -0.0\nsamples = 2\nvalue = 25.2'),
#  Text(0.27358490566037735, 0.4583333333333333, 'X[1] <= 97.85\nsquared_error = 0.002\nsamples = 3\nvalue = 24.867'),
#  Text(0.2688679245283019, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 24.9'),
#  Text(0.2783018867924528, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.30660377358490565, 0.625, 'X[0] <= 1.044\nsquared_error = 0.287\nsamples = 9\nvalue = 23.967'),
#  Text(0.2971698113207547, 0.5416666666666666, 'X[3] <= 105.6\nsquared_error = 0.018\nsamples = 5\nvalue = 24.42'),
#  Text(0.29245283018867924, 0.4583333333333333, 'X[0] <= 1.043\nsquared_error = 0.007\nsamples = 4\nvalue = 24.475'),
#  Text(0.28773584905660377, 0.375, 'X[2] <= 105.8\nsquared_error = 0.003\nsamples = 2\nvalue = 24.55'),
#  Text(0.2830188679245283, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 24.6'),
#  Text(0.29245283018867924, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 24.5'),
#  Text(0.2971698113207547, 0.375, 'squared_error = -0.0\nsamples = 2\nvalue = 24.4'),
#  Text(0.3018867924528302, 0.4583333333333333, 'squared_error = -0.0\nsamples = 1\nvalue = 24.2'),
#  Text(0.3160377358490566, 0.5416666666666666, 'X[0] <= 1.046\nsquared_error = 0.045\nsamples = 4\nvalue = 23.4'),
#  Text(0.3113207547169811, 0.4583333333333333, 'squared_error = 0.0\nsamples = 2\nvalue = 23.6'),
#  Text(0.32075471698113206, 0.4583333333333333, 'X[0] <= 1.046\nsquared_error = 0.01\nsamples = 2\nvalue = 23.2'),
#  Text(0.3160377358490566, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.32547169811320753, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.41745283018867924, 0.7083333333333334, 'X[0] <= 1.051\nsquared_error = 1.394\nsamples = 41\nvalue = 20.995'),
#  Text(0.37971698113207547, 0.625, 'X[0] <= 1.049\nsquared_error = 0.346\nsamples = 23\nvalue = 21.891'),
#  Text(0.3561320754716981, 0.5416666666666666, 'X[0] <= 1.048\nsquared_error = 0.088\nsamples = 12\nvalue = 22.383'),
#  Text(0.3443396226415094, 0.4583333333333333, 'X[2] <= 100.05\nsquared_error = 0.02\nsamples = 5\nvalue = 22.7'),
#  Text(0.33490566037735847, 0.375, 'X[4] <= 155.375\nsquared_error = 0.007\nsamples = 3\nvalue = 22.8'),
#  Text(0.330188679245283, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 22.9'),
#  Text(0.33962264150943394, 0.2916666666666667, 'X[1] <= 87.95\nsquared_error = 0.002\nsamples = 2\nvalue = 22.75'),
#  Text(0.33490566037735847, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 22.8'),
#  Text(0.3443396226415094, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 22.7'),
#  Text(0.35377358490566035, 0.375, 'X[2] <= 105.15\nsquared_error = 0.003\nsamples = 2\nvalue = 22.55'),
#  Text(0.3490566037735849, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 22.5'),
#  Text(0.3584905660377358, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.36792452830188677, 0.4583333333333333, 'X[0] <= 1.048\nsquared_error = 0.014\nsamples = 7\nvalue = 22.157'),
#  Text(0.3632075471698113, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 22.4'),
#  Text(0.37264150943396224, 0.375, 'X[2] <= 101.65\nsquared_error = 0.005\nsamples = 6\nvalue = 22.117'),
#  Text(0.36792452830188677, 0.2916666666666667, 'X[0] <= 1.049\nsquared_error = 0.002\nsamples = 4\nvalue = 22.075'),
#  Text(0.3632075471698113, 0.20833333333333334, 'squared_error = -0.0\nsamples = 3\nvalue = 22.1'),
#  Text(0.37264150943396224, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 22.0'),
#  Text(0.37735849056603776, 0.2916666666666667, 'squared_error = -0.0\nsamples = 2\nvalue = 22.2'),
#  Text(0.4033018867924528, 0.5416666666666666, 'X[0] <= 1.05\nsquared_error = 0.075\nsamples = 11\nvalue = 21.355'),
#  Text(0.3867924528301887, 0.4583333333333333, 'X[0] <= 1.05\nsquared_error = 0.028\nsamples = 5\nvalue = 21.6'),
#  Text(0.38207547169811323, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 21.8'),
#  Text(0.3915094339622642, 0.375, 'X[3] <= 99.95\nsquared_error = 0.002\nsamples = 3\nvalue = 21.467'),
#  Text(0.3867924528301887, 0.2916666666666667, 'squared_error = -0.0\nsamples = 2\nvalue = 21.5'),
#  Text(0.39622641509433965, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 21.4'),
#  Text(0.419811320754717, 0.4583333333333333, 'X[0] <= 1.051\nsquared_error = 0.022\nsamples = 6\nvalue = 21.15'),
#  Text(0.41037735849056606, 0.375, 'X[0] <= 1.05\nsquared_error = 0.003\nsamples = 4\nvalue = 21.25'),
#  Text(0.4056603773584906, 0.2916666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 21.3'),
#  Text(0.41509433962264153, 0.2916666666666667, 'X[3] <= 105.15\nsquared_error = 0.0\nsamples = 2\nvalue = 21.2'),
#  Text(0.41037735849056606, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.419811320754717, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.42924528301886794, 0.375, 'X[4] <= 181.5\nsquared_error = 0.003\nsamples = 2\nvalue = 20.95'),
#  Text(0.42452830188679247, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 20.9'),
#  Text(0.4339622641509434, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.455188679245283, 0.625, 'X[0] <= 1.054\nsquared_error = 0.396\nsamples = 18\nvalue = 19.85'),
#  Text(0.4386792452830189, 0.5416666666666666, 'X[0] <= 1.052\nsquared_error = 0.058\nsamples = 9\nvalue = 20.433'),
#  Text(0.4339622641509434, 0.4583333333333333, 'squared_error = 0.0\nsamples = 2\nvalue = 20.8'),
#  Text(0.44339622641509435, 0.4583333333333333, 'X[1] <= 91.0\nsquared_error = 0.025\nsamples = 7\nvalue = 20.329'),
#  Text(0.4386792452830189, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 20.1'),
#  Text(0.4481132075471698, 0.375, 'X[0] <= 1.052\nsquared_error = 0.006\nsamples = 5\nvalue = 20.42'),
#  Text(0.44339622641509435, 0.2916666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 20.5'),
#  Text(0.4528301886792453, 0.2916666666666667, 'X[2] <= 104.1\nsquared_error = 0.002\nsamples = 3\nvalue = 20.367'),
#  Text(0.4481132075471698, 0.20833333333333334, 'squared_error = 0.0\nsamples = 2\nvalue = 20.4'),
#  Text(0.45754716981132076, 0.20833333333333334, 'squared_error = -0.0\nsamples = 1\nvalue = 20.3'),
#  Text(0.4716981132075472, 0.5416666666666666, 'X[0] <= 1.054\nsquared_error = 0.053\nsamples = 9\nvalue = 19.267'),
#  Text(0.46226415094339623, 0.4583333333333333, 'X[3] <= 106.75\nsquared_error = 0.002\nsamples = 3\nvalue = 19.533'),
#  Text(0.45754716981132076, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 19.5'),
#  Text(0.4669811320754717, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.4811320754716981, 0.4583333333333333, 'X[4] <= 175.125\nsquared_error = 0.026\nsamples = 6\nvalue = 19.133'),
#  Text(0.47641509433962265, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 18.8'),
#  Text(0.4858490566037736, 0.375, 'X[0] <= 1.055\nsquared_error = 0.004\nsamples = 5\nvalue = 19.2'),
#  Text(0.4811320754716981, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.49056603773584906, 0.2916666666666667, 'X[0] <= 1.055\nsquared_error = 0.002\nsamples = 4\nvalue = 19.175'),
#  Text(0.4858490566037736, 0.20833333333333334, 'squared_error = 0.0\nsamples = 3\nvalue = 19.2'),
#  Text(0.49528301886792453, 0.20833333333333334, 'squared_error = -0.0\nsamples = 1\nvalue = 19.1'),
#  Text(0.7778596698113207, 0.875, 'X[0] <= 1.073\nsquared_error = 21.71\nsamples = 96\nvalue = 11.947'),
#  Text(0.6506485849056604, 0.7916666666666666, 'X[0] <= 1.065\nsquared_error = 7.183\nsamples = 57\nvalue = 14.953'),
#  Text(0.5890330188679245, 0.7083333333333334, 'X[0] <= 1.061\nsquared_error = 1.387\nsamples = 31\nvalue = 16.903'),
#  Text(0.5459905660377359, 0.625, 'X[0] <= 1.058\nsquared_error = 0.329\nsamples = 18\nvalue = 17.761'),
#  Text(0.5165094339622641, 0.5416666666666666, 'X[1] <= 91.55\nsquared_error = 0.074\nsamples = 9\nvalue = 18.256'),
#  Text(0.5, 0.4583333333333333, 'X[4] <= 161.0\nsquared_error = 0.015\nsamples = 4\nvalue = 18.0'),
#  Text(0.49528301886792453, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 17.8'),
#  Text(0.5047169811320755, 0.375, 'X[2] <= 95.45\nsquared_error = 0.002\nsamples = 3\nvalue = 18.067'),
#  Text(0.5, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 18.0'),
#  Text(0.5094339622641509, 0.2916666666666667, 'X[1] <= 88.8\nsquared_error = 0.0\nsamples = 2\nvalue = 18.1'),
#  Text(0.5047169811320755, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 18.1'),
#  Text(0.5141509433962265, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 18.1'),
#  Text(0.5330188679245284, 0.4583333333333333, 'X[0] <= 1.057\nsquared_error = 0.026\nsamples = 5\nvalue = 18.46'),
#  Text(0.5235849056603774, 0.375, 'X[4] <= 181.75\nsquared_error = 0.003\nsamples = 2\nvalue = 18.65'),
#  Text(0.5188679245283019, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 18.6'),
#  Text(0.5283018867924528, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 18.7'),
#  Text(0.5424528301886793, 0.375, 'X[0] <= 1.057\nsquared_error = 0.002\nsamples = 3\nvalue = 18.333'),
#  Text(0.5377358490566038, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 18.4'),
#  Text(0.5471698113207547, 0.2916666666666667, 'X[3] <= 100.0\nsquared_error = 0.0\nsamples = 2\nvalue = 18.3'),
#  Text(0.5424528301886793, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 18.3'),
#  Text(0.5518867924528302, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 18.3'),
#  Text(0.5754716981132075, 0.5416666666666666, 'X[0] <= 1.06\nsquared_error = 0.096\nsamples = 9\nvalue = 17.267'),
#  Text(0.5660377358490566, 0.4583333333333333, 'X[0] <= 1.059\nsquared_error = 0.026\nsamples = 5\nvalue = 17.52'),
#  Text(0.5613207547169812, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 17.7'),
#  Text(0.5707547169811321, 0.375, 'X[4] <= 182.25\nsquared_error = 0.007\nsamples = 3\nvalue = 17.4'),
#  Text(0.5660377358490566, 0.2916666666666667, 'X[2] <= 97.4\nsquared_error = 0.003\nsamples = 2\nvalue = 17.45'),
#  Text(0.5613207547169812, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 17.4'),
#  Text(0.5707547169811321, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 17.5'),
#  Text(0.5754716981132075, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 17.3'),
#  Text(0.5849056603773585, 0.4583333333333333, 'X[0] <= 1.06\nsquared_error = 0.002\nsamples = 4\nvalue = 16.95'),
#  Text(0.5801886792452831, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 17.0'),
#  Text(0.589622641509434, 0.375, 'squared_error = -0.0\nsamples = 2\nvalue = 16.9'),
#  Text(0.6320754716981132, 0.625, 'X[0] <= 1.063\nsquared_error = 0.423\nsamples = 13\nvalue = 15.715'),
#  Text(0.6179245283018868, 0.5416666666666666, 'X[0] <= 1.062\nsquared_error = 0.094\nsamples = 7\nvalue = 16.257'),
#  Text(0.6037735849056604, 0.4583333333333333, 'X[0] <= 1.061\nsquared_error = 0.007\nsamples = 3\nvalue = 16.6'),
#  Text(0.5990566037735849, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 16.7'),
#  Text(0.6084905660377359, 0.375, 'X[3] <= 105.5\nsquared_error = 0.002\nsamples = 2\nvalue = 16.55'),
#  Text(0.6037735849056604, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 16.6'),
#  Text(0.6132075471698113, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 16.5'),
#  Text(0.6320754716981132, 0.4583333333333333, 'X[4] <= 188.625\nsquared_error = 0.005\nsamples = 4\nvalue = 16.0'),
#  Text(0.6273584905660378, 0.375, 'X[1] <= 93.15\nsquared_error = 0.002\nsamples = 3\nvalue = 16.033'),
#  Text(0.6226415094339622, 0.2916666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 16.0'),
#  Text(0.6320754716981132, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 16.1'),
#  Text(0.6367924528301887, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 15.9'),
#  Text(0.6462264150943396, 0.5416666666666666, 'X[2] <= 89.95\nsquared_error = 0.065\nsamples = 6\nvalue = 15.083'),
#  Text(0.6415094339622641, 0.4583333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 15.6'),
#  Text(0.6509433962264151, 0.4583333333333333, 'X[1] <= 94.1\nsquared_error = 0.014\nsamples = 5\nvalue = 14.98'),
#  Text(0.6462264150943396, 0.375, 'X[2] <= 95.05\nsquared_error = 0.002\nsamples = 4\nvalue = 14.925'),
#  Text(0.6415094339622641, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 15.0'),
#  Text(0.6509433962264151, 0.2916666666666667, 'X[1] <= 87.55\nsquared_error = 0.0\nsamples = 3\nvalue = 14.9'),
#  Text(0.6462264150943396, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 14.9'),
#  Text(0.6556603773584906, 0.20833333333333334, 'squared_error = -0.0\nsamples = 2\nvalue = 14.9'),
#  Text(0.6556603773584906, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 15.2'),
#  Text(0.7122641509433962, 0.7083333333333334, 'X[0] <= 1.07\nsquared_error = 4.148\nsamples = 26\nvalue = 12.627'),
#  Text(0.6745283018867925, 0.625, 'X[2] <= 90.0\nsquared_error = 7.526\nsamples = 12\nvalue = 13.458'),
#  Text(0.6650943396226415, 0.5416666666666666, 'X[0] <= 1.067\nsquared_error = 15.602\nsamples = 2\nvalue = 9.55'),
#  Text(0.660377358490566, 0.4583333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 5.6'),
#  Text(0.6698113207547169, 0.4583333333333333, 'squared_error = -0.0\nsamples = 1\nvalue = 13.5'),
#  Text(0.6839622641509434, 0.5416666666666666, 'X[4] <= 148.75\nsquared_error = 2.244\nsamples = 10\nvalue = 14.24'),
#  Text(0.6792452830188679, 0.4583333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 18.5'),
#  Text(0.6886792452830188, 0.4583333333333333, 'X[0] <= 1.068\nsquared_error = 0.253\nsamples = 9\nvalue = 13.767'),
#  Text(0.6792452830188679, 0.375, 'X[2] <= 99.25\nsquared_error = 0.107\nsamples = 7\nvalue = 13.986'),
#  Text(0.6745283018867925, 0.2916666666666667, 'X[0] <= 1.067\nsquared_error = 0.026\nsamples = 6\nvalue = 13.867'),
#  Text(0.6650943396226415, 0.20833333333333334, 'X[0] <= 1.067\nsquared_error = 0.007\nsamples = 3\nvalue = 14.0'),
#  Text(0.660377358490566, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 14.1'),
#  Text(0.6698113207547169, 0.125, 'X[4] <= 165.125\nsquared_error = 0.002\nsamples = 2\nvalue = 13.95'),
#  Text(0.6650943396226415, 0.041666666666666664, 'squared_error = 0.0\nsamples = 1\nvalue = 14.0'),
#  Text(0.6745283018867925, 0.041666666666666664, 'squared_error = 0.0\nsamples = 1\nvalue = 13.9'),
#  Text(0.6839622641509434, 0.20833333333333334, 'X[3] <= 95.15\nsquared_error = 0.009\nsamples = 3\nvalue = 13.733'),
#  Text(0.6792452830188679, 0.125, 'squared_error = 0.0\nsamples = 2\nvalue = 13.8'),
#  Text(0.6886792452830188, 0.125, 'squared_error = -0.0\nsamples = 1\nvalue = 13.6'),
#  Text(0.6839622641509434, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 14.7'),
#  Text(0.6981132075471698, 0.375, 'X[2] <= 93.5\nsquared_error = 0.01\nsamples = 2\nvalue = 13.0'),
#  Text(0.6933962264150944, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 13.1'),
#  Text(0.7028301886792453, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 12.9'),
#  Text(0.75, 0.625, 'X[0] <= 1.071\nsquared_error = 0.153\nsamples = 14\nvalue = 11.914'),
#  Text(0.7311320754716981, 0.5416666666666666, 'X[0] <= 1.071\nsquared_error = 0.018\nsamples = 6\nvalue = 12.317'),
#  Text(0.7216981132075472, 0.4583333333333333, 'X[0] <= 1.071\nsquared_error = 0.005\nsamples = 4\nvalue = 12.4'),
#  Text(0.7169811320754716, 0.375, 'X[2] <= 92.3\nsquared_error = 0.002\nsamples = 3\nvalue = 12.433'),
#  Text(0.7122641509433962, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 12.5'),
#  Text(0.7216981132075472, 0.2916666666666667, 'X[3] <= 95.8\nsquared_error = 0.0\nsamples = 2\nvalue = 12.4'),
#  Text(0.7169811320754716, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 12.4'),
#  Text(0.7264150943396226, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 12.4'),
#  Text(0.7264150943396226, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 12.3'),
#  Text(0.7405660377358491, 0.4583333333333333, 'X[1] <= 88.0\nsquared_error = 0.002\nsamples = 2\nvalue = 12.15'),
#  Text(0.7358490566037735, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 12.1'),
#  Text(0.7452830188679245, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 12.2'),
#  Text(0.7688679245283019, 0.5416666666666666, 'X[0] <= 1.072\nsquared_error = 0.041\nsamples = 8\nvalue = 11.612'),
#  Text(0.7594339622641509, 0.4583333333333333, 'X[0] <= 1.072\nsquared_error = 0.005\nsamples = 4\nvalue = 11.8'),
#  Text(0.7547169811320755, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 11.9'),
#  Text(0.7641509433962265, 0.375, 'X[0] <= 1.072\nsquared_error = 0.002\nsamples = 3\nvalue = 11.767'),
#  Text(0.7594339622641509, 0.2916666666666667, 'X[4] <= 155.5\nsquared_error = 0.0\nsamples = 2\nvalue = 11.8'),
#  Text(0.7547169811320755, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 11.8'),
#  Text(0.7641509433962265, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 11.8'),
#  Text(0.7688679245283019, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 11.7'),
#  Text(0.7783018867924528, 0.4583333333333333, 'X[0] <= 1.073\nsquared_error = 0.007\nsamples = 4\nvalue = 11.425'),
#  Text(0.7735849056603774, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 11.5'),
#  Text(0.7830188679245284, 0.375, 'X[4] <= 157.75\nsquared_error = 0.002\nsamples = 2\nvalue = 11.35'),
#  Text(0.7783018867924528, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 11.4'),
#  Text(0.7877358490566038, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 11.3'),
#  Text(0.9050707547169812, 0.7916666666666666, 'X[0] <= 1.082\nsquared_error = 10.439\nsamples = 39\nvalue = 7.554'),
#  Text(0.8537735849056604, 0.7083333333333334, 'X[0] <= 1.078\nsquared_error = 1.094\nsamples = 21\nvalue = 9.438'),
#  Text(0.8254716981132075, 0.625, 'X[0] <= 1.076\nsquared_error = 0.293\nsamples = 13\nvalue = 10.154'),
#  Text(0.8066037735849056, 0.5416666666666666, 'X[0] <= 1.074\nsquared_error = 0.066\nsamples = 6\nvalue = 10.667'),
#  Text(0.7971698113207547, 0.4583333333333333, 'X[3] <= 88.65\nsquared_error = 0.007\nsamples = 3\nvalue = 10.9'),
#  Text(0.7924528301886793, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 10.8'),
#  Text(0.8018867924528302, 0.375, 'X[3] <= 93.5\nsquared_error = 0.002\nsamples = 2\nvalue = 10.95'),
#  Text(0.7971698113207547, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 11.0'),
#  Text(0.8066037735849056, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 10.9'),
#  Text(0.8160377358490566, 0.4583333333333333, 'X[4] <= 166.25\nsquared_error = 0.016\nsamples = 3\nvalue = 10.433'),
#  Text(0.8113207547169812, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 10.6'),
#  Text(0.8207547169811321, 0.375, 'X[4] <= 186.45\nsquared_error = 0.002\nsamples = 2\nvalue = 10.35'),
#  Text(0.8160377358490566, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 10.4'),
#  Text(0.8254716981132075, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 10.3'),
#  Text(0.8443396226415094, 0.5416666666666666, 'X[0] <= 1.077\nsquared_error = 0.07\nsamples = 7\nvalue = 9.714'),
#  Text(0.8349056603773585, 0.4583333333333333, 'X[4] <= 145.625\nsquared_error = 0.007\nsamples = 3\nvalue = 10.0'),
#  Text(0.8301886792452831, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 9.9'),
#  Text(0.839622641509434, 0.375, 'X[1] <= 81.8\nsquared_error = 0.002\nsamples = 2\nvalue = 10.05'),
#  Text(0.8349056603773585, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 10.1'),
#  Text(0.8443396226415094, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 10.0'),
#  Text(0.8537735849056604, 0.4583333333333333, 'X[2] <= 96.0\nsquared_error = 0.01\nsamples = 4\nvalue = 9.5'),
#  Text(0.8490566037735849, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 9.4'),
#  Text(0.8584905660377359, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 9.6'),
#  Text(0.8820754716981132, 0.625, 'X[0] <= 1.081\nsquared_error = 0.209\nsamples = 8\nvalue = 8.275'),
#  Text(0.8679245283018868, 0.5416666666666666, 'X[0] <= 1.079\nsquared_error = 0.036\nsamples = 5\nvalue = 8.6'),
#  Text(0.8632075471698113, 0.4583333333333333, 'squared_error = 0.0\nsamples = 2\nvalue = 8.8'),
#  Text(0.8726415094339622, 0.4583333333333333, 'X[0] <= 1.08\nsquared_error = 0.016\nsamples = 3\nvalue = 8.467'),
#  Text(0.8679245283018868, 0.375, 'X[2] <= 91.55\nsquared_error = 0.003\nsamples = 2\nvalue = 8.55'),
#  Text(0.8632075471698113, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 8.6'),
#  Text(0.8726415094339622, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 8.5'),
#  Text(0.8773584905660378, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 8.3'),
#  Text(0.8962264150943396, 0.5416666666666666, 'X[0] <= 1.082\nsquared_error = 0.029\nsamples = 3\nvalue = 7.733'),
#  Text(0.8915094339622641, 0.4583333333333333, 'X[1] <= 82.75\nsquared_error = 0.002\nsamples = 2\nvalue = 7.85'),
#  Text(0.8867924528301887, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 7.9'),
#  Text(0.8962264150943396, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 7.8'),
#  Text(0.9009433962264151, 0.4583333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 7.5'),
#  Text(0.9563679245283019, 0.7083333333333334, 'X[2] <= 107.35\nsquared_error = 12.368\nsamples = 18\nvalue = 5.356'),
#  Text(0.9516509433962265, 0.625, 'X[0] <= 1.089\nsquared_error = 4.06\nsamples = 17\nvalue = 4.647'),
#  Text(0.9268867924528302, 0.5416666666666666, 'X[0] <= 1.085\nsquared_error = 0.45\nsamples = 9\nvalue = 6.211'),
#  Text(0.910377358490566, 0.4583333333333333, 'X[0] <= 1.083\nsquared_error = 0.098\nsamples = 5\nvalue = 6.74'),
#  Text(0.9056603773584906, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 7.1'),
#  Text(0.9150943396226415, 0.375, 'X[1] <= 78.2\nsquared_error = 0.02\nsamples = 3\nvalue = 6.5'),
#  Text(0.910377358490566, 0.2916666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 6.6'),
#  Text(0.9198113207547169, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 6.3'),
#  Text(0.9433962264150944, 0.4583333333333333, 'X[1] <= 83.65\nsquared_error = 0.102\nsamples = 4\nvalue = 5.55'),
#  Text(0.9339622641509434, 0.375, 'X[4] <= 143.0\nsquared_error = 0.003\nsamples = 2\nvalue = 5.25'),
#  Text(0.9292452830188679, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 5.2'),
#  Text(0.9386792452830188, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 5.3'),
#  Text(0.9528301886792453, 0.375, 'X[3] <= 101.6\nsquared_error = 0.023\nsamples = 2\nvalue = 5.85'),
#  Text(0.9481132075471698, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 5.7'),
#  Text(0.9575471698113207, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.9764150943396226, 0.5416666666666666, 'X[4] <= 126.625\nsquared_error = 2.274\nsamples = 8\nvalue = 2.888'),
#  Text(0.9669811320754716, 0.4583333333333333, 'X[4] <= 122.125\nsquared_error = 0.122\nsamples = 2\nvalue = 0.35'),
#  Text(0.9622641509433962, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.9716981132075472, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 0.7'),
#  Text(0.9858490566037735, 0.4583333333333333, 'X[0] <= 1.092\nsquared_error = 0.129\nsamples = 6\nvalue = 3.733'),
#  Text(0.9811320754716981, 0.375, 'X[0] <= 1.091\nsquared_error = 0.026\nsamples = 5\nvalue = 3.88'),
#  Text(0.9716981132075472, 0.2916666666666667, 'X[0] <= 1.09\nsquared_error = 0.007\nsamples = 3\nvalue = 4.0'),
#  Text(0.9669811320754716, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 4.1'),
#  Text(0.9764150943396226, 0.20833333333333334, 'X[1] <= 74.0\nsquared_error = 0.002\nsamples = 2\nvalue = 3.95'),
#  Text(0.9716981132075472, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.9811320754716981, 0.125, 'squared_error = -0.0\nsamples = 1\nvalue = 3.9'),
#  Text(0.9905660377358491, 0.2916666666666667, 'X[3] <= 92.5\nsquared_error = 0.0\nsamples = 2\nvalue = 3.7'),
#  Text(0.9858490566037735, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 3.7'),
#  Text(0.9952830188679245, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 3.7'),
#  Text(0.9905660377358491, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.9610849056603774, 0.625, 'squared_error = -0.0\nsamples = 1\nvalue = 17.4')]

# %%
path = dtr.cost_complexity_pruning_path(X_train, y_train)
ccp_alpha = path.ccp_alphas

# %%
alphalist = []
for i in range(len(ccp_alpha)):
    dtr = DecisionTreeRegressor(ccp_alpha=ccp_alpha[i])
    dtr.fit(X_train, y_train)
    alphalist.append(dtr)

# %%
train_score = [alphalist[i].score(X_train, y_train) for i in range(len(alphalist))]
test_score = [alphalist[i].score(X_test, y_test) for i in range(len(alphalist))]

# %%
plt.plot(ccp_alpha, train_score, marker='o', label='trainig', drawstyle='steps-post')
plt.plot(ccp_alpha, test_score, marker='*', label='testing', drawstyle='steps-post')
plt.xlabel("alpha")
plt.ylabel("accuracy")
plt.legend()
plt.show()

# %%
dtr_1 = DecisionTreeRegressor(ccp_alpha=1)
dtr_1.fit(X_train, y_train)
y_pred = dtr_1.predict(X_test)
print(f'Decision Tree : {metrics.r2_score(y_test, y_pred)}')
# Out:
# Decision Tree : 0.921824877075662

# %%
rf = RandomForestRegressor(n_estimators=1000, ccp_alpha=1)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
print(f'Random Forest : {metrics.r2_score(y_test, y_pred_rf)}')
# Out:
# Random Forest : 0.9355439417209992

# %% [markdown]
# ### Hyperparameter Tuning

# %%
params = {
    'RandomForest': {
        'model':RandomForestRegressor(),
        'params':{
            'n_estimators': [int(x) for x in np.linspace(start=1, stop=1200,num=100)],
#             'criterion': ['squared_error','mae'],
            'max_depth': [int(x) for x in np.linspace(start=1, stop=30,num=5)],
            'min_samples_split': [2,5,10,12],
            'min_samples_leaf': [2,5,10,12],
            'max_features':['sqrt'],
            'ccp_alpha': [1,2,2.5,3,3.5,4.5],
        } 
    },
    
    'Decision-Tree': {
        'model':DecisionTreeRegressor(),
        'params':{
#             'criterion': ['squared_error','mae'],
            'splitter':['best','random'],
            'min_samples_split': [2,5,10,12,15],
            'min_samples_leaf': [2,5,10,12,15],
            'max_features':['sqrt'],
            'ccp_alpha': [1,2,2.5,3,3.5,4.5],
        } 
    },
    
    'SVM':{
        'model': SVR(),
        'params':{
            'C':[0.25,0.50,0.75,1.0],
            'tol':[1e-10,1e-5,1e-4,0.025,0.50,0.75],
            'kernel':['linear', 'poly', 'rbf','sigmoid'],
            'max_iter': [int(x) for x in np.linspace(start=1, stop=250,num=10)],
        }
    }
}

# %%
scores=[]
for modelname, mp in params.items():
    clf = RandomizedSearchCV(mp['model'], param_distributions=mp['params'],
                            cv=5, n_jobs=-1,n_iter=10, scoring='neg_mean_squared_error')
    
    clf.fit(X_train, y_train)
    scores.append({
        'modelname':modelname,
        'bestscore':clf.best_score_,
        'bestestimator':clf.best_estimator_
    })
# Out:
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\svm\_base.py:301: ConvergenceWarning: Solver terminated early (max_iter=194).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %%
scores_df = pd.DataFrame(scores, columns=['modelname', 'bestscore', 'bestestimator'])
scores_df
# Out:
#        modelname  bestscore                                      bestestimator
# 0   RandomForest  -5.318473  (DecisionTreeRegressor(ccp_alpha=1, max_depth=...
# 1  Decision-Tree -10.292179  DecisionTreeRegressor(ccp_alpha=1, max_feature...
# 2            SVM -28.821049  SVR(C=0.5, kernel='poly', max_iter=194, tol=0....

# %%
scores[0]['bestestimator']
# Out:
# RandomForestRegressor(ccp_alpha=1, max_depth=22, max_features='sqrt',
#                       min_samples_leaf=2, n_estimators=655)

# %%
rf1 = scores[0]['bestestimator']

# %%
rf1.fit(X_train, y_train)
# Out:
# RandomForestRegressor(ccp_alpha=1, max_depth=22, max_features='sqrt',
#                       min_samples_leaf=2, n_estimators=655)

# %%
y_pred_rf1 = rf1.predict(X_test)

# %%
metrics.r2_score(y_test, y_pred_rf1)
# Out:
# 0.9077762611918146

# %%
df_train_list = np.array(df_train)
predicted = []
for i in range(len(df_train_list)):
    predicted.append(rf1.predict([df_train_list[i]]))

df_train['Actual Result']=test_data
df_train['Predicted Result']=np.array(predicted)
# Out:
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\953223614.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Actual Result']=test_data
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\953223614.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Predicted Result']=np.array(predicted)

# %%
df_train
# Out:
#      Density  Abdomen  Chest    Hip  Weight  Actual Result  Predicted Result
# 0     1.0708     85.2   93.1   94.5  154.25           12.3         12.155106
# 1     1.0853     83.0   93.6   98.7  173.25            6.1          8.494415
# 2     1.0414     87.9   95.8   99.2  154.00           25.3         23.138149
# 3     1.0751     86.4  101.8  101.2  184.75           10.4         11.301296
# 4     1.0340    100.0   97.3  101.9  184.25           28.7         27.326610
# ..       ...      ...    ...    ...     ...            ...               ...
# 247   1.0736     83.6   89.2   88.8  134.25           11.0         10.617633
# 248   1.0236    105.0  108.5  104.5  201.00           33.6         30.282122
# 249   1.0328    111.5  111.1  101.7  186.75           29.3         29.114252
# 250   1.0399    101.3  108.3   97.8  190.75           26.0         26.023274
# 251   1.0271    108.5  112.4  107.1  207.50           31.9         30.557028
#
# [252 rows x 7 columns]

# %%
sns.distplot(df_train['Actual Result'],label='Actual Result', hist=False)
sns.distplot(df_train['Predicted Result'],label='Predicted Result', hist=False)
plt.legend()
plt.plot()
# Out:
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\2884055517.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_train['Actual Result'],label='Actual Result', hist=False)
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\2884055517.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_train['Predicted Result'],label='Predicted Result', hist=False)
# []

# %%
rf = RandomForestRegressor(n_estimators=1000, ccp_alpha=1)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(ccp_alpha=1, n_estimators=1000)

# %%
y_pred_rf = rf.predict(X_test)

# %%
metrics.r2_score(y_test, y_pred_rf)
# Out:
# 0.9362523009156222

# %%
df_train.drop(['Actual Result','Predicted Result'], axis=1, inplace=True)
# Out:
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\1232749926.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train.drop(['Actual Result','Predicted Result'], axis=1, inplace=True)

# %%
df_train_list = np.array(df_train)
predicted = []
for i in range(len(df_train_list)):
    predicted.append(rf1.predict([df_train_list[i]]))

df_train['Actual Result']=test_data
df_train['Predicted Result']=np.array(predicted)
# Out:
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\953223614.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Actual Result']=test_data
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\953223614.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Predicted Result']=np.array(predicted)

# %%
df_train
# Out:
#      Density  Abdomen  Chest    Hip  Weight  Actual Result  Predicted Result
# 0     1.0708     85.2   93.1   94.5  154.25           12.3         12.155106
# 1     1.0853     83.0   93.6   98.7  173.25            6.1          8.494415
# 2     1.0414     87.9   95.8   99.2  154.00           25.3         23.138149
# 3     1.0751     86.4  101.8  101.2  184.75           10.4         11.301296
# 4     1.0340    100.0   97.3  101.9  184.25           28.7         27.326610
# ..       ...      ...    ...    ...     ...            ...               ...
# 247   1.0736     83.6   89.2   88.8  134.25           11.0         10.617633
# 248   1.0236    105.0  108.5  104.5  201.00           33.6         30.282122
# 249   1.0328    111.5  111.1  101.7  186.75           29.3         29.114252
# 250   1.0399    101.3  108.3   97.8  190.75           26.0         26.023274
# 251   1.0271    108.5  112.4  107.1  207.50           31.9         30.557028
#
# [252 rows x 7 columns]

# %%
sns.distplot(df_train['Actual Result'],label='Actual Result', hist=False)
sns.distplot(df_train['Predicted Result'],label='Predicted Result', hist=False)
plt.legend()
plt.plot()
# Out:
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\2884055517.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_train['Actual Result'],label='Actual Result', hist=False)
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_10880\2884055517.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_train['Predicted Result'],label='Predicted Result', hist=False)
# []

# %% [markdown]
# ##### As we can see the normal aaproach Random Forest performs well then the Random Forest model with hyperparameter tuning. So we will be using a normal approach Random Forest model as it predict close to the actual values.

# %%
#Saving model
file=open('bodyfatmodel.pkl','wb')
pickle.dump(rf,file)
file.close()
